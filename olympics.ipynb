# %%
import pandas as pd

# %%
# Load the CSV files
world_population = pd.read_csv('data/world_population.csv')
gdp_data = pd.read_csv('data/gdp_data.csv')

# Load and split the Summer Olympic Medals data
olympic_medals = pd.read_csv('data/Summer_olympic_Medals.xls', names=['Year', 'Host_country', 'Host_city', 'Country_Name', 'Country_Code', 'Gold', 'Silver', 'Bronze'])

# %%
# Merge world_population with gdp_data
population_gdp = pd.merge(world_population, gdp_data, left_on='CCA3', right_on='Code', how='inner')

# %%
# Ensure both 'Year' columns are of the same type (int64)
population_gdp['Year'] = population_gdp['Year'].astype(str)
olympic_medals['Year'] = olympic_medals['Year'].astype(str)

# %%
# Merge the resulting DataFrame with olympic_medals
merged_data = pd.merge(population_gdp, olympic_medals, left_on=['Country/Territory', 'Year'], right_on=['Country_Name', 'Year'], how='inner')

# %%
# Drop rows with any null values
cleaned_data = merged_data.dropna()

# %%
# Save the cleaned DataFrame to a new CSV file
cleaned_data.to_csv('data/merged_cleaned_data.csv', index=False)

# %%
cleaned_data.head()
# Out:
#    Rank CCA3 Country/Territory  Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan    Kabul      Asia         41128771
# 1    36  AFG       Afghanistan    Kabul      Asia         41128771
# 2    34  DZA           Algeria  Algiers    Africa         44903225
# 3    34  DZA           Algeria  Algiers    Africa         44903225
# 4    34  DZA           Algeria  Algiers    Africa         44903225
#
#    2020 Population  2015 Population  2010 Population  2000 Population  ...  \
# 0         38972230         33753499         28189672         19542982  ...
# 1         38972230         33753499         28189672         19542982  ...
# 2         43451666         39543154         35856344         30774621  ...
# 3         43451666         39543154         35856344         30774621  ...
# 4         43451666         39543154         35856344         30774621  ...
#
#    GDP-Growth  GDP-Per-Capita           GDP   Host_country    Host_city  \
# ...
