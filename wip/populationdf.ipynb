# %%
import pandas as pd

# %%
populationdf = pd.read_csv('population.csv')

# %%
populationdf.head()
# Out:
#     Unnamed: 0        Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0         Name            Region       GENC       Year  Total Population
# 1      -> 1950               NaN        NaN        NaN                --
# 2  Afghanistan  1950,Afghanistan         AF       1950         8,150,368
# 3      Albania      1950,Albania         AL       1950         1,227,156
# 4      Algeria      1950,Algeria         DZ       1950         8,892,718
#
#     Unnamed: 5                      Unnamed: 6            Unnamed: 7  \
# 0  Growth Rate  Population Density (per sq km)  Total Fertility Rate
# 1           --                              --                    --
# 2           --                            12.5                    --
# 3           --                            44.8                    --
# 4           --                             3.7                    --
#
#                  Unnamed: 8              Unnamed: 9  \
# 0  Life Expectancy at Birth  Under-5 Mortality Rate
# ...

# %%
#keep the columns that are not needed
population = populationdf['Name', 'Total Population', 'Year']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Name', 'Total Population', 'Year')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
# ...
